# %%
import pandas as pd
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt

# %%
def parse_output(output):
    df = pd.DataFrame()
    for line in output:
        line = line.replace('\n', '')
        parsed_line = list(filter(lambda x: x.strip()!='', line.split(' ')))
        df = df.append({"time": parsed_line[0], 'port': parsed_line[1], 'value': (parsed_line[2])}, ignore_index=True)
    return df

def process_file(f, filename):
    lines = f.readlines()

    df = parse_output(lines)
    df['file'] = file
    
    # agrupo por time, file
    df = df.groupby(['time', 'file']).apply(lambda x: dict(x.values)).reset_index()

    # mapeo los valores en forma de dict a columnas
    df = df.drop([0], axis=1).join(df[0].apply(pd.Series))

    return df

# %% [markdown]
# Primero parseamos los datos que obtenemos del output para que sea más cómodo

# %%
import os

df = pd.DataFrame()
for file in os.listdir():
    if (not file.startswith('sim')):
        continue
    
    with open(file + '/output', 'r') as f:
        current_df = process_file(f, file)
        df = df.append(current_df)
df
# Out:
#                time         file sun_radiation sun_degree obtained_energy  \
# 0    00:06:00:000:0    sim-tol-1       9.14000  -35.01000         0.00000
# 1    00:12:00:000:0    sim-tol-1       9.14000  -35.19000         0.00000
# 2    00:18:00:000:0    sim-tol-1       9.14000  -35.34000         0.00000
# 3    00:24:00:000:0    sim-tol-1       9.14000  -35.46000         0.00000
# 4    00:30:00:000:0    sim-tol-1       9.14000  -35.53000         0.00000
# 5    00:36:00:000:0    sim-tol-1       9.14000  -35.57000         0.00000
# 6    00:42:00:000:0    sim-tol-1       9.14000  -35.58000         0.00000
# 7    00:48:00:000:0    sim-tol-1       9.14000  -35.54000         0.00000
# 8    00:54:00:000:0    sim-tol-1       9.14000  -35.47000         0.00000
# 9    01:00:00:000:0    sim-tol-1       9.14000  -35.36000         0.00000
# 10   01:06:00:000:0    sim-tol-1       9.14000  -35.21000         0.00000
# 11   01:12:00:000:0    sim-tol-1       9.14000  -35.03000         0.00000
# 12   01:18:00:000:0    sim-tol-1       9.14000  -34.81000         0.00000
# 13   01:24:00:000:0    sim-tol-1       9.14000  -34.55000         0.00000
# 14   01:30:00:000:0    sim-tol-1       9.14000  -34.26000         0.00000
# 15   01:36:00:000:0    sim-tol-1       9.14000  -33.94000         0.00000
# 16   01:42:00:000:0    sim-tol-1       9.14000  -33.58000         0.00000
# 17   01:48:00:000:0    sim-tol-1       9.14000  -33.19000         0.00000
# 18   01:54:00:000:0    sim-tol-1       9.14000  -32.76000         0.00000
# 19   02:00:00:000:0    sim-tol-1       9.14000  -32.30000         0.00000
# 20   02:06:00:000:0    sim-tol-1       9.14000  -31.81000         0.00000
# 21   02:12:00:000:0    sim-tol-1       9.14000  -31.29000         0.00000
# 22   02:18:00:000:0    sim-tol-1       9.14000  -30.74000         0.00000
# 23   02:24:00:000:0    sim-tol-1       9.14000  -30.17000         0.00000
# 24   02:30:00:000:0    sim-tol-1       9.14000  -29.56000         0.00000
# 4           0.00000      0.00000
# 5           0.00000      0.00000
# 6           0.00000      0.00000
# 7           0.00000      0.00000
# 8           0.00000      0.00000
# 9           0.00000      0.00000
# 10          0.00000      0.00000
# 11          0.00000      0.00000
# 12          0.00000      0.00000
# 13          0.00000      0.00000
# 14          0.00000      0.00000
# 15          0.00000      0.00000
# 16          0.00000      0.00000
# 17          0.00000      0.00000
# 18          0.00000      0.00000
# 19          0.00000      0.00000
# 20          0.00000      0.00000
# 21          0.00000      0.00000
# 22          0.00000      0.00000
# 23          0.00000      0.00000
# 24          0.00000      0.00000
# 25          0.00000      0.00000
# 26          0.00000      0.00000
# 27          0.00000      0.00000
# 28          0.00000      0.00000
# 29          0.00000      0.00000
# ..              ...          ...
# 450         0.00000  32329.69661
# 451         0.00000  32329.69661
# 452         0.00000  32329.69661
# 453         0.00000  32329.69661
# 454         0.00000  32329.69661
# 455         0.00000  32329.69661
# 456         0.00000  32329.69661
# 457         0.00000  32329.69661
# 458         0.00000  32329.69661
# 459         0.00000  32329.69661
# 460         0.00000  32329.69661
# 461         0.00000  32329.69661
# 462         0.00000  32329.69661
# 463         0.00000  32329.69661
# 464         0.00000  32329.69661
# 465         0.00000  32329.69661
# 466         0.00000  32329.69661
# 467         0.00000  32329.69661
# 468         0.00000  32329.69661
# 469         0.00000  32329.69661
# 470         0.00000  32329.69661
# 471         0.00000  32329.69661
# 472         0.00000  32329.69661
# 473         0.00000  32329.69661
# 474         0.00000  32329.69661
# 475         0.00000  32329.69661
# 476         0.00000  32329.69661
# 477         0.00000  32329.69661
# 478         0.00000  32329.69661
# 479         0.00000  32329.69661
#
# [1920 rows x 7 columns]

# %% [markdown]
# Agregamos una columna con las energía neta obtenida en cada instante

# %%
obtained_energies = df['obtained_energy'].apply(lambda x: float(x))
consumed_energies = df['consumed_energy'].apply(lambda x: float(x))
df['net_obtained_energy'] = obtained_energies - consumed_energies

# %%
fig = plt.figure()
plt.figure(figsize=(16, 6))

ax = sns.scatterplot(x='time', y='net_obtained_energy',data=df, hue='file', s=30)
ax.xaxis.set_major_locator(ticker.LinearLocator(30))
plt.xticks(rotation=45, ha='right')
plt.title("Net energy obtained for each 6 mins.")
# Out:
# Text(0.5, 1.0, 'Net energy obtained for each 6 mins.')

# %% [markdown]
# Tomamos el último valor de la batería de cada simulación, que nos dice cuanta energía se acumuló en total.

# %%
batteries = df.groupby('file')['battery'].last().reset_index()
batteries['battery'] = batteries['battery'].apply(lambda x: float(x))
batteries
# Out:
#           file      battery
# 0    sim-tol-1  32299.72661
# 1  sim-tol-100  32329.69661
# 2  sim-tol-200  32329.69661
# 3  sim-tol-300  32329.69661

# %%
plt.figure(figsize=(5, 5))

ax = sns.barplot(x='file', y='battery',data=batteries)
plt.title("Total net energy obtained")
# Out:
# Text(0.5, 1.0, 'Total net energy obtained')
